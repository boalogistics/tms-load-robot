# %%
from selenium import webdriver
from datetime import date, datetime, timedelta
from selenium.webdriver.support.ui import Select, WebDriverWait
from selenium.webdriver.support import expected_conditions as EC
import time
import os
import pandas as pd

from pynput.keyboard import Key, Controller
from IPython.display import display, HTML

#Get Load Numbers from File
filepath = r'C:\Users\boa.sokchu\Desktop\Reports\ReDelivery.xlsx'

df = pd.read_excel(filepath)
#df = data[0]
#df.fillna('',inplace=True)
#print(df)
load_list = df['Load #']#.to_string(index = False)

# removes last row of column and convert to string
#last = len(load_list_full) - 1
#load_list = load_list_full[0:last]
#load_list = map(str, load_list_int)
#print(load_list)



# activate chrome driver
browser = webdriver.Chrome()
browser.maximize_window()
browser.get("https://boa.3plsystemscloud.com/")

# page elements to login
boa_user = browser.find_element_by_id("txb-username")
boa_pw = browser.find_element_by_id("txb-password")
login_button = browser.find_element_by_id("ctl00_ContentBody_butLogin")

# login credentials
boa_user.send_keys("sokchu@boalogistics.com")
boa_pw.send_keys("Immuneact10!")
login_button.click()

for x in load_list:
    #Open edit stops page
    try:
        load_id = x
        #print(load_id)
        load_id = str(load_id)
        load_url = 'http://boa.3plsystemscloud.com/App_BW/staff/shipment/shipmentDetail.aspx?loadid='+load_id
        browser.get(load_url)

        CommodityInfo = browser.find_element_by_id('ctl00_BodyContent_tblCommodities').text
        ReDeliveryAgent = CommodityInfo.split("Re-Delivery Fee - ",1)[1][0:4]
        print(load_id + ", " + ReDeliveryAgent) #load_id + ", " + 
    except:
        pass
   
browser.quit()
print("Done!")
# Out:
# 180026, JNVE
# 180028, BUDR
# 180030, PERI
# 180031, SLST
# 180049, BUDR
# 180054, RTIT
# 180055, RTIT
# 180068, STBI
# 180102, STBI
# 180103, BUDR
# 180148, TBOA
# 180151, STBI
# 180152, ARME
# 180233, SLST
# 180295, STBI
# 180304, STBI
# 180325, EXEX
# 180327, STBI
# 180329, BUDR
# 180331, STBI
# 180340, GRTR
# 180353, STBI
# 180370, STBI
# 180411, DTSI
# 180456, BUDR
# 180457, BUDR
# 180459, BUDR
# 180522, STBI
# 180525, ATGC
# 180527, STBI
# 180536, BERR
# 180538, STBI
# 180539, TBOA
# 180546, ATGC
# 180547, ATGC
# 180548, TBOA
# 180549, ATGC
# 180560, BUDR
# 180564, RTIT
# 180572, TBOA
# 180623, RTIT
# 180634, BERR
# 180642, JNVE
# 180765, RTIT
# 180772, TBOA
# 180845, BUDR
# 180856, SLST
# 180930, STBI
# 180931, STBI
# 180932, JNVE
# 180939, CANN
# 180946, TBOA
# 180986, WSTR
# 181042, STBI
# 181063, STBI
# 181065, STBI
# 181067, STBI
# 181071, STBI
# 181080, STBI
# 181114, BUDR
# 181130, ATGC
# 181166, RTIT
# 181194, BUDR
# 181219, TBOA
# 181230, STBI
# 181237, BUDR
# ...
